# %% [markdown]
# # 2015 Local Government Area Profiles
# "DHHS develops [the LGA Statistical Profiles](https://discover.data.vic.gov.au/dataset/2015-local-government-area-profiles) on an annual basis, to support and inform health and human service planning and policy development. The profiles contain data for all 79 LGAs, as well as for DHHS Areas and former Regions."

# %%
import pandas as pd
import re

# %%
lga = pd.read_excel("2015-Local_Government_Area_Profiles.xlsx", sheet_name='LGAs')

# %%
# area = lga[['LGA Name', 'Area of LGA (km2)', 'Distance to Melbourne']]
# obese = lga[['LGA Name', 'People reporting being obese', 'People reporting being obese (rank)', 'People reporting being pre-obese', 'People reporting being pre-obese (rank)']]
# dietary = lga[['LGA Name', 'People who do not meet dietary guidelines for either fruit or vegetable consumption', 'People who do not meet dietary guidelines for either fruit or vegetable consumption (rank)']]
# exercise = lga[['LGA Name', 'People who do not meet physical activity guidelines', 'People who do not meet physical activity guidelines (rank)']]
# sports = lga[['LGA Name', 'People who are members of a sports group', 'People who are members of a sports group (rank)']]

# %%
profiles = lga[['LGA Name', 'Area of LGA (km2)', 'People reporting type 2 diabetes', 'People reporting type 2 diabetes (rank)', 'People reporting being obese', 'People reporting being obese (rank)', 'People reporting being pre-obese', 'People reporting being pre-obese (rank)', 'People who do not meet dietary guidelines for either fruit or vegetable consumption', 'People who do not meet dietary guidelines for either fruit or vegetable consumption (rank)', 'People who do not meet physical activity guidelines', 'People who do not meet physical activity guidelines (rank)', 'People who are members of a sports group', 'People who are members of a sports group (rank)']]

# %%
profiles
# Out:
#             LGA Name Area of LGA (km2) People reporting type 2 diabetes  \
# 0         Alpine (S)           4,787.0                             5.0%
# 1        Ararat (RC)           4,210.0                             3.6%
# 2       Ballarat (C)             739.0                             3.9%
# 3        Banyule (C)              63.0                             3.6%
# 4     Bass Coast (S)             865.0                             5.1%
# ..               ...               ...                              ...
# 75       Wyndham (C)             542.0                             4.4%
# 76         Yarra (C)              20.0                             3.5%
# 77  Yarra Ranges (S)           2,465.0                             3.9%
# 78  Yarriambiack (S)           7,326.0                             5.7%
# 79          Victoria               NaN                             5.0%
#
#     People reporting type 2 diabetes (rank) People reporting being obese  \
# ...

# %%
profiles = profiles.iloc[:79]
profiles = profiles.sort_values('LGA Name')

# %%
Name = profiles['LGA Name']

# %%
govt = []
status = []
for name in Name:
    if '(C)' in name:
        status.append('City')
    elif '(RC)' in name:
        status.append('Rural City')
    elif '(B)' in name:
        status.append('Borough')
    else: 
        status.append('Shire')
    name = re.sub(r'\W*\(\w*\)', '', name)
    govt.append(name)

# %%
profiles['LGA Name'] = govt
profiles.insert(1, 'LGA status', status)

# %%
profiles
# Out:
#         LGA Name  LGA status Area of LGA (km2)  \
# 0         Alpine       Shire           4,787.0
# 1         Ararat  Rural City           4,210.0
# 2       Ballarat        City             739.0
# 3        Banyule        City              63.0
# 4     Bass Coast       Shire             865.0
# ..           ...         ...               ...
# 74       Wodonga  Rural City             433.0
# 75       Wyndham        City             542.0
# 76         Yarra        City              20.0
# 77  Yarra Ranges       Shire           2,465.0
# 78  Yarriambiack       Shire           7,326.0
#
#    People reporting type 2 diabetes  People reporting type 2 diabetes (rank)  \
# 0                              5.0%                                     35.0
# 1                              3.6%                                     67.0
# 2                              3.9%                                     61.0
# 3                              3.6%                                     66.0
# ...

# %%
profiles.to_csv("csv-profiles.csv", index=False)
